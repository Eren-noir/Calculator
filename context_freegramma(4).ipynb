# %% [markdown]
# <a href="https://colab.research.google.com/github/Eren-noir/Calculator/blob/main/context_freegramma(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tree import Tree
from nltk.draw import tree
from nltk import CFG

# %%
grammar4 = CFG.fromstring ("""
S -> NP VP | NP AUX VP
NP -> PROM | NOM | NPR | NPR NOM
NOM -> N | N PP
VP -> TV NP AUX NP | TV NP | IV
AUX -> 'unaweza'| 'ya'
N -> 'ndege' | 'ngari moshi'
TV -> 'kuhifadhi'
PROM -> 'wewe'
NPR -> 'mombasa'
""")

# %%
sent =" wewe unaweza kuhifadhi ndege ya mombasa".split()
rd_parser = nltk.RecursiveDescentParser(grammar4)
for tree in rd_parser.parse(sent):
     print(tree)
# Out:
# (S
#   (NP (PROM wewe))
#   (AUX unaweza)
#   (VP
#     (TV kuhifadhi)
#     (NP (NOM (N ndege)))
#     (AUX ya)
#     (NP (NPR mombasa))))

# %%
nltk.app.rdparser()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_2564/2115078367.py in <cell line: 0>()
# ----> 1 nltk.app.rdparser()
#
# /usr/local/lib/python3.12/dist-packages/nltk/app/rdparser_app.py in app()
#    1044     sent = "the dog saw a man in the park".split()
#    1045
# -> 1046     RecursiveDescentApp(grammar, sent).mainloop()
#    1047
#    1048
#
# /usr/local/lib/python3.12/dist-packages/nltk/app/rdparser_app.py in __init__(self, grammar, sent, trace)
#      91
#      92         # Set up the main window.
# ---> 93         self._top = Tk()
#      94         self._top.title("Recursive Descent Parser Application")
#      95
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# ...

# %%
from nltk.grammar import *
grammar4.productions(lhs=Nonterminal("NP"))

# %%
groucho_grammar = nltk.CFG.fromstring("""
 S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
 P -> 'in'
""")

# %%
groucho_grammar.productions(lhs=terminal("Det"))

# %%
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
trees = list(parser.parse(sent))
print(trees [1])

# %%
for tree in parser.parse(sent):
      print(tree)

# %%
# expect a pop up menu
tree = Tree.fromstring("(S(NP I)(VP(VP (V shot) (NP (Det an) (N elephant)))(PP (P in) (NP (Det my) (N pajamas)))))")
tree.draw()

# %%
grammar4.start()

# %%
grammar4.productions()

# %%
grammar1 = CFG.fromstring("""
 S -> A B
 A -> 'a'
 # An empty production:
 B -> 'b' |
 """)

# %%
grammar2 = nltk.CFG.fromstring("""
  S -> NP VP
  VP -> V NP | V NP PP
  PP -> P NP
  V -> "saw" | "ate" | "walked"
  NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
  Det -> "a" | "an" | "the" | "my"
  N -> "man" | "dog" | "cat" | "telescope" | "park"
  P -> "in" | "on" | "by" | "with"
  """)

# %%
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar2)
for tree in rd_parser.parse(sent):
     print(tree)

# %%
nltk.app.rdparser()

# %%
sr_parser = nltk.ShiftReduceParser(grammar2)
sent = 'Mary saw a dog'.split()
for tree in sr_parser.parse(sent):
    print(tree)

# %%
nltk.app.chartparser()
